# %% [markdown]
# <a href="https://colab.research.google.com/github/pratheekshashetty-blip/machinelearningprojects/blob/main/Customer_Segementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mall Customer Segmentation using Machine Learning
#
# Objective:
# Segment mall customers based on income and spending behaviour
# using clustering algorithms such as K-Means and DBSCAN.

# %% [markdown]
# Dataset: https://www.kaggle.com/datasets/shwetabh123/mall-customers

# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import silhouette_score

# %%
# Load data

df = pd.read_csv('Mall_Customers.csv')
df.columns = ['CustomerID', 'Genre', 'Age', 'Income', 'Spending']

print(df.shape)
print(df.describe())
print(df.isnull().sum())
# Out:
# (200, 5)
#        CustomerID         Age      Income    Spending
# count  200.000000  200.000000  200.000000  200.000000
# mean   100.500000   38.850000   60.560000   50.200000
# std     57.879185   13.969007   26.264721   25.823522
# min      1.000000   18.000000   15.000000    1.000000
# 25%     50.750000   28.750000   41.500000   34.750000
# 50%    100.500000   36.000000   61.500000   50.000000
# 75%    150.250000   49.000000   78.000000   73.000000
# max    200.000000   70.000000  137.000000   99.000000
# CustomerID    0
# Genre         0
# Age           0
# Income        0
# Spending      0
# dtype: int64

# %%
#  Scale features
X = df[['Income', 'Spending']].values
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
#Find optimal k — Elbow + Silhouette
inertias, sil_scores = [], []
K = range(2, 11)

for k in K:
    km = KMeans(n_clusters=k, random_state=42, n_init=10)
    km.fit(X_scaled)
    inertias.append(km.inertia_)
    sil_scores.append(silhouette_score(X_scaled, km.labels_))

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].plot(list(K), inertias, marker='o')
axes[0].set_title('Elbow Method')
axes[0].set_xlabel('Number of Clusters')
axes[0].set_ylabel('Inertia')

axes[1].plot(list(K), sil_scores, marker='o', color='green')
axes[1].set_title('Silhouette Score')
axes[1].set_xlabel('Number of Clusters')
axes[1].set_ylabel('Score')
plt.tight_layout()
plt.show()

# %%
print(df[["Income","Spending","Segment"]].head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_211/4223073714.py in <cell line: 0>()
# ----> 1 print(df[["Income","Spending","Segment"]].head())
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6250
#    6251             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252             raise KeyError(f"{not_found} not in index")
#    6253
#    6254     @overload
#
# KeyError: "['Segment'] not in index"

# %%
# K-Means (k=5)
kmeans = KMeans(n_clusters=5, random_state=42, n_init=10)
df['kmeans_cluster'] = kmeans.fit_predict(X_scaled)

segment_map = {
0: "Standard Customers",
1: "Target Customers",
2: "Impulsive Spenders",
3: "Cautious Customers",
4: "Budget Customers"
}

df["Segment"] = df["kmeans_cluster"].map(segment_map)
plt.figure(figsize=(8, 6))
for cluster in sorted(df['kmeans_cluster'].unique()):
    subset = df[df['kmeans_cluster'] == cluster]
    plt.scatter(subset['Income'], subset['Spending'],label=segment_map[cluster], s=50)

centers = scaler.inverse_transform(kmeans.cluster_centers_)
plt.scatter(centers[:, 0], centers[:, 1], c='black', marker='X', s=200, label='Centroids')
plt.title('K-Means Clustering (k=5)')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score')
plt.legend()
plt.tight_layout()
plt.show()
plt.close()

# %%
#  Cluster analysis
summary = df.groupby('kmeans_cluster')[['Income', 'Spending', 'Age']].mean().round(1)
summary['count'] = df.groupby('kmeans_cluster').size()
print('\nCluster Summary:')
print(summary)
# Out:
# Cluster Summary:
#                 Income  Spending   Age  count
# kmeans_cluster
# 0                 55.3      49.5  42.7     81
# 1                 86.5      82.1  32.7     39
# 2                 25.7      79.4  25.3     22
# 3                 88.2      17.1  41.1     35
# 4                 26.3      20.9  45.2     23

# %%
# DBSCAN

dbscan = DBSCAN(eps=0.45, min_samples=5)
df['dbscan_cluster'] = dbscan.fit_predict(X_scaled)

plt.figure(figsize=(8, 6))
for cluster in sorted(df['dbscan_cluster'].unique()):
    subset = df[df['dbscan_cluster'] == cluster]
    label = 'Noise' if cluster == -1 else f'Cluster {cluster}'
    marker = 'x' if cluster == -1 else 'o'
    plt.scatter(subset['Income'], subset['Spending'], label=label, marker=marker, s=50)

plt.title('DBSCAN Clustering')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score')
plt.legend()
plt.tight_layout()
plt.show()
plt.close()


print(f"\nDBSCAN — clusters: {df['dbscan_cluster'].nunique() - 1}, noise points: {(df['dbscan_cluster'] == -1).sum()}")
# Out:
# DBSCAN — clusters: 3, noise points: 11

# %% [markdown]
# Model Evaluation

# %%
from sklearn.metrics import silhouette_score

score = silhouette_score(X, kmeans.labels_)
print("Silhouette Score:", score)
# Out:
# Silhouette Score: 0.553931997444648

# %%
score = silhouette_score(X, dbscan.labels_)
print("DBSCAN Silhouette Score:", score)
# Out:
# DBSCAN Silhouette Score: 0.3200802658739474

# %% [markdown]
# This project applied unsupervised ML techniqes to segment Mall coustomer spendings based on their annual income and spending behaviour.

# %% [markdown]
# The analysis identified five distinct customer groups with different purchasing behaviors. These clusters can help businesses better understand their customers and design targeted marketing strategies.

# %% [markdown]
# Both DBSCAN and Kmeans were used, but KMeans provided clearer and more meaningful customer segments for this dataset.

# %% [markdown]
# Predict the category of your customer and strategy to be used:

# %%
strategy_map = {
    "Standard Customers": "Offer regular discounts, loyalty programs, and personalized product suggestions.",
    "Target Customers": "Provide premium services, exclusive deals, and high-value product recommendations.",
    "Impulsive Spenders": "Use flash sales, bundle offers, and trend-based promotions to increase purchases.",
    "Cautious Customers": "Focus on trust-building, clear product value, and offers that emphasize smart spending.",
    "Budget Customers": "Highlight affordability, discounts, and budget-friendly product options."
}

print("Enter the details of your customer")

income = float(input("Annual Income (k$): "))
spending = float(input("Spending Score (1-100): "))

new_customer = [[income, spending]]
new_customer_scaled = scaler.transform(new_customer)

predicted_cluster = kmeans.predict(new_customer_scaled)[0]
predicted_segment = segment_map[predicted_cluster]
predicted_strategy = strategy_map[predicted_segment]

print("\nYour predicted segment is:", predicted_segment)
print("Suggested marketing strategy:", predicted_strategy)
# Out:
# Enter the details of your customer
# Annual Income (k$): 1200
# Spending Score (1-100): 30
#
# Your predicted segment is: Cautious Customers
# Suggested marketing strategy: Focus on trust-building, clear product value, and offers that emphasize smart spending.
